# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
file_one = Path("../02_Dataset/hadr-21-22.csv")

# %%
# Read our data file with the Pandas Library
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
pd.set_option('display.max_columns', None)

# %%
file_one_df.head()
# Out:
#       FAC_NO                      FAC_NAME  BEG_DATE    END_DATE  DAY_PER  \
# 0  106580996  ADVENTIST HEALTH AND RIDEOUT  1/1/2021  12/31/2021      365
# 1  106150788  ADVENTIST HEALTH BAKERSFIELD  1/1/2021  12/31/2021      365
# 2  106171049    ADVENTIST HEALTH CLEARLAKE  1/1/2021  12/31/2021      365
# 3  106150706       ADVENTIST HEALTH DELANO  1/1/2021  12/31/2021      365
# 4  106190323     ADVENTIST HEALTH GLENDALE  1/1/2021  12/31/2021      365
#
#   DATA_IND              AUDIT_IND       COUNTY  HSA  HFPA  TYPE_CNTRL  \
# 0  Audited  Incl. Ind. Audit Adj.         Yuba    2   227  Non-Profit
# 1  Audited  Incl. Ind. Audit Adj.         Kern    9   617  Non-Profit
# 2  Audited  Incl. Ind. Audit Adj.         Lake    1   115  Non-Profit
# 3  Audited  Incl. Ind. Audit Adj.         Kern    9   617  Non-Profit
# 4  Audited  Excl. Ind. Audit Adj.  Los Angeles   11   909  Non-Profit
#
#   TYPE_CARE   TYPE_HOSP TEACH_RURL         PHONE              ADDRESS  \
# ...

# %%
hadr_21_22_df = file_one_df[['FAC_NO', 'FAC_NAME', 'BEG_DATE', 'END_DATE', 'DAY_PER', 'COUNTY', 'TYPE_CNTRL', 'TYPE_CARE', 'ADDRESS', 'CITY', 'ZIP_CODE', 'OWNER', 'DIS_ACUTE', 'DIS_PSYCH', 'DIS_CHEM', 'DIS_REHAB', 'DIS_LTC', 'DIS_RESDNT', 'NETRV_MCAR_TR', 'NETRV_MCAR_MC', 'NETRV_MCAL_TR', 'NETRV_MCAL_MC', 'NETRV_CNTY', 'NETRV_THRD_TR', 'NETRV_THRD_MC', 'NETRV_OTH_IND', 'NETRV_OTH', 'TOT_ASST']]

# %%
hadr_21_22_df.tail()
# Out:
#         FAC_NO                                           FAC_NAME  BEG_DATE  \
# 437  106190857                         WEST COVINA MEDICAL CENTER  1/1/2022
# 438  106190859             WEST HILLS HOSPITAL AND MEDICAL CENTER  1/1/2021
# 439  106190883                   WHITTIER HOSPITAL MEDICAL CENTER  7/1/2021
# 440  106571086                         WOODLAND MEMORIAL HOSPITAL  7/1/2021
# 441  106380939  ZUCKERBERG SAN FRANCISCO GENERAL HOSPITAL & TR...  7/1/2021
#
#        END_DATE  DAY_PER         COUNTY   TYPE_CNTRL TYPE_CARE  \
# 437   6/20/2022      171    Los Angeles     Investor   General
# 438  12/31/2021      365    Los Angeles     Investor   General
# 439   6/30/2022      365    Los Angeles     Investor   General
# 440   6/30/2022      365           Yolo   Non-Profit   General
# 441   6/30/2022      365  San Francisco  City/County   General
#
#                         ADDRESS           CITY ZIP_CODE  \
# 437  725 SOUTH ORANGE BOULEVARD    WEST COVINA    91790
# ...

# %%
filtered_df = hadr_21_22_df[hadr_21_22_df['DAY_PER'] >= 365]
filtered_df.tail()
# Out:
#         FAC_NO                                           FAC_NAME  BEG_DATE  \
# 436  106190857                         WEST COVINA MEDICAL CENTER  1/1/2021
# 438  106190859             WEST HILLS HOSPITAL AND MEDICAL CENTER  1/1/2021
# 439  106190883                   WHITTIER HOSPITAL MEDICAL CENTER  7/1/2021
# 440  106571086                         WOODLAND MEMORIAL HOSPITAL  7/1/2021
# 441  106380939  ZUCKERBERG SAN FRANCISCO GENERAL HOSPITAL & TR...  7/1/2021
#
#        END_DATE  DAY_PER         COUNTY   TYPE_CNTRL TYPE_CARE  \
# 436  12/31/2021      365    Los Angeles     Investor   General
# 438  12/31/2021      365    Los Angeles     Investor   General
# 439   6/30/2022      365    Los Angeles     Investor   General
# 440   6/30/2022      365           Yolo   Non-Profit   General
# 441   6/30/2022      365  San Francisco  City/County   General
#
#                         ADDRESS           CITY ZIP_CODE  \
# 436  725 SOUTH ORANGE BOULEVARD    WEST COVINA    91790
# ...

# %%
acute_filtered_df = hadr_21_22_df[hadr_21_22_df['DIS_ACUTE'] > 1]
hadr_21_22.tail()
# Out:
#         FAC_NO                                           FAC_NAME  BEG_DATE  \
# 419  106381154                                UCSF MEDICAL CENTER  7/1/2021
# 422  106370782  UNIVERSITY OF CALIFORNIA SAN DIEGO MEDICAL CENTER  7/1/2021
# 84   106100717         COMMUNITY REGIONAL MEDICAL CENTER - FRESNO  9/1/2020
# 421  106301279     UNIVERSITY OF CALIFORNIA IRVINE MEDICAL CENTER  7/1/2021
# 57   106190555                        CEDARS-SINAI MEDICAL CENTER  7/1/2021
#
#       END_DATE  DAY_PER         COUNTY  TYPE_CNTRL TYPE_CARE  \
# 419  6/30/2022      365  San Francisco  Non-Profit   General
# 422  6/30/2022      365      San Diego  Non-Profit   General
# 84   8/31/2021      365         Fresno  Non-Profit   General
# 421  6/30/2022      365         Orange  Non-Profit   General
# 57   6/30/2022      365    Los Angeles  Non-Profit   General
#
#                       ADDRESS           CITY    ZIP_CODE  \
# 419      505 PARNASSUS AVENUE  SAN FRANCISCO       94143
# ...

# %%
acuteTop_filtered_df = acute_filtered_df.sort_values(by=['TOT_ASST'], ascending=False)
acuteTop_filtered_df.head(10)
# Out:
#         FAC_NO                                           FAC_NAME   BEG_DATE  \
# 383  106430905                               STANFORD HEALTH CARE   9/1/2020
# 57   106190555                        CEDARS-SINAI MEDICAL CENTER   7/1/2021
# 419  106381154                                UCSF MEDICAL CENTER   7/1/2021
# 285  106374382                             PALOMAR MEDICAL CENTER   7/1/2021
# 323  106190796                  RONALD REAGAN UCLA MEDICAL CENTER   7/1/2021
# 420  106341006      UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER   7/1/2021
# 221  106361246               LOMA LINDA UNIVERSITY MEDICAL CENTER   7/1/2021
# 142  106301205                HOAG MEMORIAL HOSPITAL PRESBYTERIAN   1/1/2021
# 422  106370782  UNIVERSITY OF CALIFORNIA SAN DIEGO MEDICAL CENTER   7/1/2021
# 356  106370694                            SHARP MEMORIAL HOSPITAL  10/1/2020
#
#        END_DATE  DAY_PER          COUNTY  TYPE_CNTRL TYPE_CARE  \
# ...

# %%
df = pd.DataFrame(acuteTop_filtered_df, columns=["NETRV_MCAR_TR", "NETRV_MCAR_MC", "NETRV_MCAL_TR", "NETRV_MCAL_MC", "NETRV_CNTY", "NETRV_THRD_TR", "NETRV_THRD_MC", "NETRV_OTH_IND", "NETRV_OTH"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 column_average = acuteTop_filtered_df.mean(axis=0)
#
# File ~/anaconda3/envs/dev3/lib/python3.10/site-packages/pandas/core/frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~/anaconda3/envs/dev3/lib/python3.10/site-packages/pandas/core/generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# ...

# %%
acuteBottom_filtered_df = acute_filtered_df.sort_values(by=['TOT_ASST'], ascending=True)
acuteBottom_filtered_df.head(10)
# Out:
#         FAC_NO                                          FAC_NAME  BEG_DATE  \
# 171  106340913           KAISER FOUNDATION HOSPITAL - SACRAMENTO  1/1/2021
# 164  106334048        KAISER FOUNDATION HOSPITAL - MORENO VALLEY  1/1/2021
# 165  106014326     KAISER FOUNDATION HOSPITAL - OAKLAND/RICHMOND  1/1/2021
# 166  106304409  KAISER FOUNDATION HOSPITAL - ORANGE CO - ANAHEIM  1/1/2021
# 167  106190432        KAISER FOUNDATION HOSPITAL - PANORAMA CITY  1/1/2021
# 168  106414139         KAISER FOUNDATION HOSPITAL - REDWOOD CITY  1/1/2021
# 169  106334025            KAISER FOUNDATION HOSPITAL - RIVERSIDE  1/1/2021
# 170  106314024            KAISER FOUNDATION HOSPITAL - ROSEVILLE  1/1/2021
# 161  106104062               KAISER FOUNDATION HOSPITAL - FRESNO  1/1/2021
# 172  106370730            KAISER FOUNDATION HOSPITAL - SAN DIEGO  1/1/2021
#
#        END_DATE  DAY_PER       COUNTY  TYPE_CNTRL TYPE_CARE  \
# 171  12/31/2021      365   Sacramento  Non-Profit   General
# ...

# %%
acuteTop_filtered_df = acute_filtered_df.sort_values(by=['TOT_ASST'], ascending=False)
acuteTop_filtered_df.head(10)
# Out:
#         FAC_NO                                       FAC_NAME  BEG_DATE  \
# 187  106015000              KAISER FOUNDATION NORTHERN REGION  1/1/2021
# 188  106191300              KAISER FOUNDATION SOUTHERN REGION  1/1/2021
# 383  106430905                           STANFORD HEALTH CARE  9/1/2020
# 57   106190555                    CEDARS-SINAI MEDICAL CENTER  7/1/2021
# 419  106381154                            UCSF MEDICAL CENTER  7/1/2021
# 285  106374382                         PALOMAR MEDICAL CENTER  7/1/2021
# 323  106190796              RONALD REAGAN UCLA MEDICAL CENTER  7/1/2021
# 420  106341006  UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER  7/1/2021
# 221  106361246           LOMA LINDA UNIVERSITY MEDICAL CENTER  7/1/2021
# 142  106301205            HOAG MEMORIAL HOSPITAL PRESBYTERIAN  1/1/2021
#
#        END_DATE  DAY_PER          COUNTY  TYPE_CNTRL TYPE_CARE  \
# 187  12/31/2021      365             NaN  Non-Profit   General
# ...

# %%
# Out:
#         FAC_NO                                           FAC_NAME  BEG_DATE  \
# 158  106196403                KAISER FOUNDATION HOSPITAL - DOWNEY  1/1/2021
# 179  106190431             KAISER FOUNDATION HOSPITAL - SOUTH BAY  1/1/2021
# 182  106484044             KAISER FOUNDATION HOSPITAL - VACAVILLE  1/1/2021
# 181  106410806   KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO  1/1/2021
# 186  106480989  KAISER FOUNDATION HOSPITAL REHABILITATION CENT...  1/1/2021
# 157  106196035          KAISER FOUNDATION HOSPITAL - BALDWIN PARK  1/1/2021
# 156  106074097               KAISER FOUNDATION HOSPITAL - ANTIOCH  1/1/2021
# 176  106210992            KAISER FOUNDATION HOSPITAL - SAN RAFAEL  1/1/2021
# 173  106380857         KAISER FOUNDATION HOSPITAL - SAN FRANCISCO  1/1/2021
# 178  106494019            KAISER FOUNDATION HOSPITAL - SANTA ROSA  1/1/2021
#
#        END_DATE  DAY_PER         COUNTY  TYPE_CNTRL TYPE_CARE  \
# 158  12/31/2021      365    Los Angeles  Non-Profit   General
# ...

# %%
hadr_21_22_df = hadr_21_22_df.rename(columns=['fac_no', 'fac_name', 'beg_date', 'end_date', 'day_per', 'county', 'type_cntrl', 'type_care', 'address', 'city', 'zip_code', 'owner', 'dis_acute', 'dis_psych', 'dis_chem', 'dis_rehab', 'dis_ltc', 'dis_resdnt', 'netrv_mcar_tr', 'netrv_mcar_mc', 'netrv_mcal_tr', 'netrv_mcal_mc', 'netrv_cnty', 'netrv_thrd_tr', 'netrv_thrd_mc', 'netrv_oth_ind', 'netrv_oth', 'tot_asst'])
